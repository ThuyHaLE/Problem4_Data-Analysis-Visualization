# %% [markdown]
# <a href="https://colab.research.google.com/github/ThuyHaLE/Data_visualization/blob/main/Word_Clouds_Belle_(Japanese%2BChinese).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install wordcloud
# !pip3 install wordcloud==1.8.1
#Import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS
print ('Wordcloud is installed and imported!')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wordcloud: filename=wordcloud-1.8.1-cp310-cp310-linux_x86_64.whl size=441130 sha256=c0b32d5991c35f68d3142ff010859add765ff26747f53de2f2cb2c89106af710
#   Stored in directory: /root/.cache/pip/wheels/6b/b1/75/024072f28a2b9d6c4f80b35ebfd6ced7fd9fc58e9f1b933b9f
# Successfully built wordcloud
# ...
#   Attempting uninstall: wordcloud
#     Found existing installation: wordcloud 1.8.2.2
#     Uninstalling wordcloud-1.8.2.2:
#       Successfully uninstalled wordcloud-1.8.2.2
# ...
# Wordcloud is installed and imported!

# %%
#Import some library
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import urllib
import urllib.request
from PIL import Image

from google.colab import drive
drive.mount ('/content/drive')
from google.colab import files
# Out:
# Mounted at /content/drive

# %%
#Save mask to belle_mask
belle_mask = np.array(Image.open(urllib.request.urlopen(
    'https://drive.google.com/uc?export=download&id=1Gj5JPTRHn2Oj3fDTU6ZpPbCgzVYkAu9a')))
fig = plt.figure(figsize=(15, 15))
plt.imshow(belle_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Open the text file and read it into a variable belle_novel
belle_novel = urllib.request.urlopen(
    'https://drive.google.com/uc?export=download&id=1qZiBQkdpbUwJ1vmVuibp6jNkhTtmL0Nk').read().decode("utf-8")

#Let's use the stopwords that we imported from word_cloud.
#We use the function set to remove any redundant stopwords.
stopwords = set(STOPWORDS)

#Instantiate a word cloud object
belle_wc = WordCloud(
    background_color='black',
    max_words=2000000,
    mask=belle_mask,
    colormap='cool',
    font_path='/content/ProNW4.ttc', #download: https://drive.google.com/file/d/1BtUjdfBEZyUvVb0af42sy2_VmRNxJxjR/view?usp=drive_link
    stopwords=stopwords).generate(belle_novel) # generate the word cloud

#Display and save the word cloud
fig = plt.figure(figsize=(20, 20))
plt.imshow(belle_wc, interpolation='bilinear')
plt.axis('off')
plt.savefig("Belle the dragon and the freckled princess.png")
plt.show()
files.download('Belle the dragon and the freckled princess.png')
